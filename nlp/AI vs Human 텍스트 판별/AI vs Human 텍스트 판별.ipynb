# %% [markdown]
# https://dacon.io/competitions/official/236178/data

# %% [markdown]
# **[설명]**
#
# 4일 후의 프로젝트를 위해 준비된 이 데이터셋에는 인간이 작성한 리뷰와 인공지능이 작성한 리뷰가 섞여 있습니다.
#
# 하지만 어떤 리뷰가 인간에 의해 작성되었는지를 나타내는 레이블 대부분이 사라져버렸습니다.
#
# 여러분의 임무는 일부 레이블이 남아있는 학습용 데이터셋을 활용하여,
#
# 테스트 데이터셋의 네 개 리뷰 중 어떤 것이 실제 인간에 의해 작성된 것인지 정확하게 예측하는 것입니다!
#
# 당신의 통찰력을 활용하여 테스트 데이터셋의 'label' 필드를 복구해주세요!

# %% [markdown]
# * train.csv [파일]
# * id : 샘플 고유 id
# * sentence1 : 리뷰 텍스트 1
# * sentence2 : 리뷰 텍스트 2
# * sentence3 : 리뷰 텍스트 3
# * sentence4 : 리뷰 텍스트 4
# * label : 사람이 작성한 원본 리뷰 텍스트 번호; [1, 2, 3, 4] 중 하나

# %%
# drive mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# install sentencepiece
# !pip install -U transformers sentencepiece -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 19.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 48.8 MB/s eta 0:00:00

# %%
# # install cupf, cupy, cuml
# !pip install pyproject
# !git clone https://github.com/rapidsai/rapidsai-csp-utils.git
# !python rapidsai-csp-utils/colab/pip-install.py

# %% [markdown]
# # Module

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from tqdm import tqdm

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, RandomSampler, SequentialSampler

from keras.utils import pad_sequences

from transformers import AdamW
from transformers import AutoTokenizer, AutoModel

# %%
train_df = pd.read_csv(r'/content/drive/MyDrive/Share/Personal/NLP/data/train.csv')
test_df = pd.read_csv(r'/content/drive/MyDrive/Share/Personal/NLP/data/test.csv')

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         50 non-null     object
#  1   sentence1  50 non-null     object
#  2   sentence2  50 non-null     object
#  3   sentence3  50 non-null     object
#  4   sentence4  50 non-null     object
#  5   label      50 non-null     int64
# dtypes: int64(1), object(5)
# memory usage: 2.5+ KB

# %% [markdown]
# # Data Preprocessing

# %%
train_df
# Out:
#            id                                          sentence1  \
# 0   TRAIN_000  직원들 마음에 들지 않는다는 것은 알겠지만, 가지 말아야 할까? 인터넷에서 싸게 살...
# 1   TRAIN_001  분위기 최고! 2층 창문이 넓어서 공기가 통하는 느낌이에요. 조명도 멋지고 음료와 ...
# 2   TRAIN_002  일단, 장사가 잘 되길 바라는 마음에서 별 다섯 개 드립니다. 간도 딱 맞았고, 저...
# 3   TRAIN_003  1편의 독특함 때문에 살짝 뒤로 밀린 느낌이 있지만, 여전히 재미있어요. 게임 시스...
# 4   TRAIN_004  빵점 주고 싶은걸 간신히 참았다...이런건 사상 유래가 없는,조지 루카스 영감의 스...
# 5   TRAIN_005  치킨 반마리 주문 가능. 골뱅이소면과 함께 추천. 치킨은 평범, 사이드메뉴와 함께하...
# 6   TRAIN_006  진짜 일하시는 사람들 너무 시끄러워요  자기들 개인사얘기하는데 목소리도 크고 밥이 ...
# 7   TRAIN_007  우와 정말 멋진 스터디 카페입니다. 다른 지점은 가보지 않았지만, 노트북을 많이 사...
# 8   TRAIN_008  가시려는 분들은 이전 리뷰를 잘 읽어보고 가는 것을 추천합니다. 급하게 여기에서 상...
# 9   TRAIN_009  라운즈 앱에서 안경 구매 후 도수렌즈 구매했어요. 제가 눈이 나쁘고 렌즈 결정하기가...
# 10  TRAIN_010  요약 : 시나리오가 지루하고, 형사들의 행동이 답답하고 어리석았으며, 코미디 요소도...
# 11  TRAIN_011  음식이 정말 맛있어요. 동네 수준을 뛰어넘는 퀄리티를 자랑합니다. 우동 면발은 부드...
# 12  TRAIN_012  아...여기 부점장 정말 불친절하네요. 고객 대응과 말투가 너무 안 좋더라고요. 이...
# 13  TRAIN_013  도넛 사러 갔다가 정말 놀랐어요. 먼저, 손님이 직접 도넛을 집을 수 있도록 매장 ...
# 14  TRAIN_014  떡볶이의 가격은 12,000원입니다. 맛은 충분히 만족스러웠지만, 가격을 고려했을 ...
# 15  TRAIN_015  분식의 전부를 제공하는 정릉역 분식집. 떡볶이는 쌀떡, 달콤하고 덜 매운 편. 분위...
# 16  TRAIN_016  극장판 중에는 최고인데, 네티즌들이 사골에 대해 계속 언급하길래 좀 의아했는데요. ...
# 17  TRAIN_017  별한개도 주기 아까운 욕나오는곳 이런쓰레기 같은곳을 좋다고 댓글 올려논 것들은 돈먹...
# 18  TRAIN_018  주말 점심에 가족들과 함께 갔는데, 예약은 두 달 전에 했습니다. 가족들 모두 매우...
# 19  TRAIN_019  좀 든든히 먹고 싶어서 5700원짜리 직화숯불구이를 시켰는데 사진처럼 정말 맛있게 ...
# 20  TRAIN_020  김밥 메뉴가 최고. 비빔국수는 다른집에서 비빔국수보다 훨씬 맛있음. 김밥을 말거나 ...
# 21  TRAIN_021  꼬들살 냉동은 조금 아쉽지만, 채소와 고기 소스의 조합이 맛있어요. 와사비 소스도 ...
# 22  TRAIN_022  24시간 가마솥 설렁탕집. 조미료 없이 진한 국물맛. 색깔이 특이하고 콜라겐감. 국...
# 23  TRAIN_023  전설적인 작품이에요! 스토리는 정말 정밀하게 짜여져 있고, 연출도 힘차고 멋져요. ...
# 24  TRAIN_024  가성비 별로... 대 사이즈 시켰는데 소 사이즈로 오고 양도 적음. 회도 쫀득하지 ...
# 25  TRAIN_025  진짜 맛있어서 자주 갔었는데 최근에는 좀 달라졌어요ㅠ 치즈스커트는 진짜 짭짤해서 램...
# 26  TRAIN_026  [위생불량-이물질] 음식에서 이물질 나와 환불 요청했더니 회수하러 와서 확인하니까 ...
# 27  TRAIN_027  보고싶었던 영화였는데 TV에서 끊어져서 아쉬웠어요. 영화를 보면서 한편의 어른 동화...
# 28  TRAIN_028  이 가격에 이런 수준의 질이면 매우 만족스럽습니다. 비싼 생선을 사용하진 않아도, ...
# 29  TRAIN_029  세계적 명품 공연을 간접적으로라도 볼 수 있게 해준 메가박스에 감사드려요. 원래라면...
# 30  TRAIN_030  치즈렐라버거에 11% 할인 받아서 올엑스트라와 치즈추가로 9200원을 냈는데... ...
# 31  TRAIN_031  재구매한 배추김치와 총각김치가 너무 맛있어서 다시 주문했는데, 이번 김치는 저번에 ...
# 32  TRAIN_032  어제 만든 감자튀김을 주문했는데... 왜이렇게 눅눅하고 최악이었을까요? 저녁에 가면...
# 33  TRAIN_033  배달 중점. 현장 서비스 떨어짐. 음식 준비 지연. 문제 제기 시, 빠른 해결 약속...
# 34  TRAIN_034  비건 친구한테 추천받아서 여기 갔는데, 다른 비건 식당들과는 차원이 다른 맛이더라고...
# 35  TRAIN_035  후기를 잘 안 쓰는 편인데요.... 아르바이트 직원들의 서비스 마인드가 좀 부족한 ...
# 36  TRAIN_036  가게를 옮기기 전엔 자주 다녔습니다. 가성비 좋은 모밀, 하지만 가격은 올랐으며 모...
# 37  TRAIN_037  우리가 일반적으로 알고 있는 베트남 음식과는 조금 다른 맛이었어요. 그러나 맛은 좋...
# 38  TRAIN_038  정말 그지같다 .. 약국앞애 할머니 아침부터 욕지걸이에 도깨비시장 오디 가겠나 시장...
# 39  TRAIN_039  처음에는 친절했지만, 전화로 문의하면 엄청 귀찮아 하고 방문하라고 함. 여분 필름은...
# 40  TRAIN_040  숨겨진 동네 맛집입니다. 평점 없는게 안타까워 리뷰 남깁니다. 사장님은 요리하시고 ...
# 41  TRAIN_041  서비스가 약간 아쉬웠습니다. 직접 운영하는 곳이 아닌 것 같아요. 문자 안내를 받고...
# 42  TRAIN_042  카카오점수(당시 5.0점) 믿고 갔는데 대실망입니다. 마늘 떨어졌다고 안주는데 아들...
# 43  TRAIN_043  돈까스의 맛이 아주 깔끔하고 좋았습니다. 실제로는 사진에서는 잘 보이지 않지만, 두...
# 44  TRAIN_044  이 게임은 확실히 제 기대를 충족시키지 못했습니다. 레벨링, 재미, 편의성, 그래픽...
# 45  TRAIN_045  남성 직원의 태도가 왜 이렇게 공격적일까요? 식사 후 기분 좋게 카페에서 커피를 마...
# 46  TRAIN_046  이 가격에 이런 품질? 제 동네에 이런 것이 있다니 감사할 따름입니다! 도우는 쫄깃...
# 47  TRAIN_047  바로 갈았어야했는데, 치킨 메뉴가 많아서 고민하다 결국 들어갔어요. 가격은 저렴한 ...
# 48  TRAIN_048  단체로 와서 잘 먹었는데 회뿐만 아니라 술도 시키면서 먹고 있었는데 "적당히"드시라...
# 49  TRAIN_049  ★★★☆(3.5)  모둠초밥(12,000원) 가성비 좋음! 참소라를 못 먹어서 다른...
#
#                                             sentence2  \
# 0   직원들 진짜 싸가지 없어요 ㅋㅋㅋㅋ 가지 마숑  인터넷이 더 싼거 알면서도 이것저것...
# 1   분위기가 너무 좋아요! 2층 창문이 넓어서 쾌적한 느낌이에요. 조명도 아름답고 음료...
# 2   일단 장사가 잘되길 바라는 마음에서 별5개 드립니다 간도 맞았고 매운걸 좋아하는 입...
# 3   1편의 신선함에 비해 약간 빛이 바래 보이지만, 여전히 재미있게 즐길 수 있어요. ...
# 4   빵점을 주고 싶지만 참아냈습니다... 이 영화는 사상 유래가 없는 것 같아요. 조지...
# 5   둘이서 치킨 반마리 주문이 가능해서 골뱅이소면무침랑 같이 시킬 수 있었네요! 치킨맛...
# 6                        진짜 시끄러운데... 이런거 시끄러워서 돈 아까워.
# 7   와우, 정말 좋아요! 이 스터디 카페는 정말 최고예요. 다른 지점은 가보지 않았지만...
# 8   가시고자 하시는 분들은 앞서 쓴 후기 잘 읽어보고 가세요. 급해서 여기서 상견례했는...
# 9   라운즈 앱을 통해 안경과 도수 렌즈를 구입했습니다. 저의 시력이 좋지 않아서 렌즈 ...
# 10  요약 : 지루한 시나리오, 멍청한 형사들, 코미디 부실, 조연들 연기력 미흡(선우선...
# 11  음청 맛있어요 동네 퀄리티가 아닙니다 부드러운데 쫄깃한 우동면발 그자체입니다 우동 ...
# 12  아...여기 부점장 정말 불친절하네요 말투며 고객응대며.. 한심하기 그지없네요 이런...
# 13  도넛을 사러 갔는데 너무 실망했습니다. 첫째로, 도넛 가게 문을 밖으로 열어두어 손...
# 14  떡볶이 가격: 12,000원 맛은 있으나, 가격상 감동적이어야할 것 같은데 그렇지는...
# 15  우이-신설선 정릉역 앞의 분식집입니다. 떡볶이, 튀김, 순대, 어묵, 라면 등의 분...
# 16  극장판중 최고긴한데아나 ㅡㅡ네티즌들이 사골사골 하길래좀 중복이 되나보다 싶었는데 ....
# 17  이곳은 별 한 개도 아까운 곳이에요. 못마땅한 경험을 한 곳으로, 좋다는 댓글을 단...
# 18  주말 점심에 가족들과 함께 다녀왔고, 예약은 두 달 전에 했습니다. 가족 모두가 매...
# 19  좀 든든히 먹고 싶어서 5700원짜리 직화숯불구이를 시켰는데 사진처럼 나왔네요 ㅋㅋ...
# 20  이 식당의 김밥 메뉴는 정말 탁월해요. 면목동에서도 따라올 수 없는 맛이에요. 비빔...
# 21  꼬들살 냉동이 조금 아쉽지만 전체적으로 채소와 고기 소스들이 조화롭습니다. 와사비와...
# 22  24시간 가마솥에서 진짜 뼈국물 고아내는 설렁탕집. 신선설렁탕이 대중적인 맛을 위한...
# 23  전설적인 작품이에요! 오배넌의 정교한 스토리텔링과 존-바뎀의 역동적인 연출이 돋보여...
# 24  가성비 폭망이네요... '대' 사이즈 시켰는데 '소'사이즈라고 밖에는 생각할 수 없...
# 25  진짜 맛있었고 자주갔는데 왜 이래요 요즘ㅠ 치즈스커트 너무 짜고 램버거도 특유의 향...
# 26  [위생불량-이물질] 음식에서 이물질 나와 회수 및 환불 요청드리니 두조각 남았다고 ...
# 27  보고 싶었던 영화였는데 티비에서 냉정하게 방영을 거부했어요. 영화를 보는 것보다 한...
# 28  이곳의 가격 대비 품질은 꽤 인상적입니다. 물론 가격에 비추어 보면 고급 생선을 사...
# 29  세계적인 오리지널 공연을 간접적으로라도 볼 수 있어서 매우 만족스러웠습니다. 메가박...
# 30  난 분명 치즈렐라버거를 11프로 할인 받았지만 올엑스트라와 치즈추가로 9200원을 ...
# 31  재구매 했던 배추김치와 총각김치가 너무 맛있어서 또 주문했는데, 이번에는 양념이 전...
# 32  어제 만든 감자튀김을 파시나... 비온것도 아닌데 눅눅하니 최악이였네요 12시에 갔...
# 33  배달 서비스에 집중하는 바람에 현장에서는 서비스가 부족하게 느껴졌습니다. 주문이 지...
# 34  비건 식당 추천. 브루고뉴풍 리조토, 시금치페스코파스타, 노미트보울 시켰음. 샐러드...
# 35  후기를 잘 안쓰는 편이지만... 아르바이트 직원분들의 서비스 마인드는 좀 아쉬웠어요...
# 36  사장님.. 예전에 가게 옮기기 전에 자주 갔는데 싼가격에 모밀도 엄청 많이 주셔서 ...
# 37  우리가 일반적으로 알고 있는 베트남 음식과는 다른 스타일의 맛이에요. 그래도 전체적...
# 38  정말로 불쾌했습니다. 약국 앞에서 아침부터 폭언을 퍼붓는 분, 그리고 시장 상인회에...
# 39  처음에는 정말 친절하셨는데요... 전화로 문의하면 매번 귀찮아하시고, 방문하라고만 ...
# 40  숨겨진 보석 같은 맛집이에요. 평점이 없어서 아쉽지만 리뷰 남기려고 해요. 사장님이...
# 41  서비스가 최하임. 여기는 본사에서 운영하는게 아닌듯함. 문자안내받고 옷 찾으러갔는데...
# 42  카카오점수(당시 5.0점)를 믿고 방문했는데, 제 기대와는 조금 다른 경험이었습니다...
# 43  돈까스는 정말 깔끔하고 맛있어요. 사진으로는 잘 안 보이지만 두 조각인데 양이 꽤 ...
# 44  레벨링, 재미, 편의성, 그래픽 모두가 기대에 못 미친다는 느낌이었습니다. 킥스타터...
# 45  ㄹㅇ남자 직원의 말투가 조금 공격적인 것 같아서 불쾌했어요. 밥을 먹고 기분 좋게 ...
# 46  이 가격대로는 이런 퀄리티를 가진 곳이 주변에 드물다고 생각해요. 도우는 아주 쫄깃...
# 47  겉만 번지르르. 치킨메뉴 많은거+주인부부 인상보고 바로 자리박차고 나왔어야했음. 가...
# 48  단체로 방문해서 맛있게 식사를 했지만, 회뿐만 아니라 술도 함께 시켜서 먹고 있었는...
# 49  ★★★☆(3.5)  모둠초밥(12,000원), 가성비 좋아! 참소라 대신 연어로 바...
#
#                                             sentence3  \
# 0   직원들 정말 싸가지 없네요 ㅋㅋㅋㅋ 인터넷에서 더 싸게 구입할 수 있다는 걸 알면서...
# 1   분위기가 짱!! 2층 창문이 커서 탁 트여있는 느낌이에요 ㅎㅎ 조명도 예쁘고 음료랑...
# 2   일단 저는 장사가 잘되기를 바라는 마음에서 별 다섯 개를 주고 싶어요. 맛도 딱 맞...
# 3   1편의 독특함 때문에 약간의 비교가 불가피하지만, 이 게임은 여전히 흥미로워요. 시...
# 4   빵점 주고 싶을 정도로 엄청 실망했어요... 이 영화는 별들의 전쟁처럼 역사적인 작...
# 5   두 사람이서 반마리의 치킨을 주문할 수 있어서, 골뱅이소면무침을 함께 주문했습니다....
# 6   진짜 이 직장은 너무 시끄럽네요. 직원들끼리만 얘기하는게 아니라 목소리도 크고 밥먹...
# 7   와우, 정말 좋은 공부 카페예요. 다른 지점은 가본 적은 없지만, 노트북을 많이 사...
# 8   이 식당을 방문하실 분들께는 앞선 리뷰들을 잘 읽어보시고 결정하시는 것을 추천드립니...
# 9   라운즈 앱을 통해 안경과 도수렌즈를 구매하였습니다. 제 시력이 좋지 않아 렌즈 결정...
# 10  요약해보면, 시나리오가 지루하고 형사들이 답답하며 멍청해요. 코미디 요소도 재미없고...
# 11  음식이 정말 맛있었습니다. 이 동네에서는 퀄리티가 높은 편이라고 생각해요. 우동면은...
# 12  아... 이곳의 부점장은 정말 불친절하네요. 그 말투와 고객응대는... 한심하면서도...
# 13  도넛 사러갔다가 경악하고 나옴. 1. 손님이 직접 집을 수 있도록 도넛장을 바깥쪽으...
# 14  떡볶이의 가격은 12,000원으로 맛은 있지만, 가격 대비 감동을 주지는 못했습니다...
# 15  정릉역 인근에 위치한 이 분식집은 떡볶이, 튀김, 순대, 어묵, 라면 등 다양한 메...
# 16  극장판은 최고지만 네티즌들이 사골을 너무 많이 언급해서 중복되는 것 같았다. 국밥을...
# 17  별 한 개도 아까운 욕나오는 곳이라니, 정말로 쓰레기 같은 곳을 좋다고 댓글 올리신...
# 18  주말 점심에 가족들과 함께 갔는데, 예약은 두 달 전에 했어요. 모두 다 만족했고,...
# 19  들고 싶은 것이 있어서 5700원짜리 직화숯불구이를 주문했는데 사진처럼 나와서 웃겼...
# 20  김밥 메뉴가 정말 훌륭했어요. 면목동의 다른 가게와 비교해도 더 좋았습니다. 비빔국...
# 21  꼬들살 냉동이 아쉽긴 하지만 전반적으로 채소와 고기 소스들이 맛있게 어우러져 있습니...
# 22  24시간 가마솥에서 진짜 뼈국물을 내는 설렁탕집이에요. 신선한 설렁탕은 대중적인 맛...
# 23  전설적인 작품! 오배넌의 완벽한 각본! 존-바뎀의 역할 연기도 대단! 두 명의 배우...
# 24  가성비가 좋지 않다고 느껴졌어요. 대 사이즈를 시켰더니 소 사이즈로 나왔고, 회의 ...
# 25  진짜 맛있었는데 최근에는 좀 달라졌어요. 치즈스커트 너무 짜고 램버거의 특유한 향이...
# 26  [위생불량-이물질] 음식을 먹다가 이물질을 발견했어요. 환불을 요청했더니 두 조각만...
# 27  보고싶었던 영환데 티비에서 뙁! 한편의어른동화를본듯한 느낌이었어요 순수함에 힐링됐다...
# 28  여긴 이가격에 이정도면 상당한건데...... 물론 이가격에 비싼 생선을 쓰는건 아니...
# 29  이런 세계적 오리지널 명공연을 이렇게 간접적으로라도 즐길수있게 해준 메가박스에 감사...
# 30  치즈렐라 버거를 할인 받아 주문했는데, 어떤 결함이 있더라구요. 치즈추가 요청과 야...
# 31  재구매한 배추김치와 총각김치 맛이 너무 좋아서 다시 주문했는데, 이번에 받은 김치는...
# 32  어제 만든 감자튀김을 먹었는데... 조금 축축해서 별로였어요. 비가 내리지 않은 날...
# 33  배달에 너무 집중해서인지 현장에서는 서비스가 조금 부족한 것 같아요. 음료나 음식이...
# 34  비건 친구가 약속 잡을 때 여기만 간다네요ㅋㅋㅋ 브루고뉴풍 리조토, 시금치페스코파스...
# 35  후기 잘 안남기는데....  아르바이트 서비스 마인드는 뒤로 제쳐두고라도 햄버거 식...
# 36  사장님, 예전에 가게 이사하기 전에 정말 좋아했었어요. 가격이 조금 오른 것은 상관...
# 37  우리가 아는 베트남 음식이 아님. 맛있음 ㅎㅎ 반깐 특이한데 맛있음 ㅋ 쌀국수는 쌀...
# 38  도대체 무슨 상황인지... 약국 앞 할머니가 욕지거리로 아침을 시작하니, 마치 도깨...
# 39  처음에는 서비스가 친절했지만, 전화로 문의하면 너무 귀찮아 하고 방문하라고만 하더라...
# 40  숨겨진 동네 맛집이에요. 평점이 없어서 아쉬워서 리뷰를 남깁니다. 사장님은 요리하시...
# 41  서비스 측면에서는 조금 미흡했다는 느낌이 들었습니다. 아마 이곳이 본사 운영이 아닌...
# 42  카카오점수가 높아서 (당시에는 5.0점이었는데,) 기대하고 갔는데, 엄청 실망했어요...
# 43  돈까스는 깔끔하고 맛있어요. 사진에는 안 보이지만 양이 제법 많아요. 감자 고로케는...
# 44  최악중의최악 레벨링도 쓰레기 재미도 쓰레기 편의성도 쓰레기 그래픽도 쓰레기 킥스타터...
# 45  ㄹㅇ남성 직원의 태도가 왜 이렇게 공격적인지 이해할 수 없었습니다. 저는 밥을 먹고...
# 46  동네에서 이 가격에 이 정도 퀄리티면 진짜 훌륭하다고 생각합니다!! 도우 넘나 쫄깃...
# 47  겉으로는 분위기가 번지르르했습니다. 다양한 치킨 메뉴가 많고, 주인 부부의 인상도 ...
# 48  단체로 와서 잘 먹었지만 회만 먹은 것도 아니고 술도 시키면서 먹고 있을 때 "적당...
# 49  리뷰: ★★★☆(3.5) 모둠초밥(12,000원)를 시켰는데 가격 대비 맛있어요! ...
#
#                                             sentence4  label
# 0   직원들의 태도가 정말 별로였어요 ㅋㅋㅋㅋ 가볼만한 가게라는 소문을 듣고 인터넷으로 ...      2
# 1   분위기가 너무 좋아요! 2층 창문이 크고 넓어서 탁 트여있는 느낌이에요. 조명도 예...      3
# 2   먼저, 칭찬과 응원의 의미로 별 다섯 개를 주고 싶습니다. 간도 딱 맞고, 저는 매...      2
# 3   1편이 워낙 참신했던 탓에 좀 묻힌 감이 있긴 하지만 재미는 여전합니다. 시스템도 ...      4
# 4   빵점을 주고 싶었는데 참았어요... 이런 영화는 전례가 없는데, 조지 루카스의 스타...      1
# 5   두 사람이서 치킨 반마리 주문이 가능해서 골뱅이소면무침과 함께 먹을 수 있었습니다....      2
# 6   진짜 일하는 분들이 너무 시끄러웠어요. 개인적인 이야기를 할 때도 목소리가 크고, ...      1
# 7   우와 완전좋아요 스터디카페 신세계 ... 다른지점은 안가봤지만 노트북많이쓰는데 노트...      4
# 8   요즘은 리뷰를 믿기 힘들죠. 하지만 제 경험을 공유하고자 해요. 급하게 가서 상견례...      2
# 9   라운즈 앱으로 안경 구매 및 도수렌즈 선택. 눈 상태 때문에 까다롭지만 직원 친절함...      1
# 10  요약 : 지루한시나리오,답답하고 멍청한형사들,재미없는 코미디,조연의 존재감이 너무없...      4
# 11  음식이 정말 맛있어요. 동네 음식점 수준이 아닌 부드럽고 쫄깃한 우동 면발이에요. ...      2
# 12  여기 점주의 태도와 응대 방식은 정말로 불친절하다고 느껴집니다. 서비스 업을 하는 ...      2
# 13  도넛 사러 갔는데 너무 실망했어요. \n1. 도넛장이 바깥으로 열려있어서 손님이 직...      3
# 14  떡볶이 가격이 12,000원인데 그에 비해 만족감은 부족합니다. 맛은 좋지만 가격 ...      2
# 15  정릉역 근처에 위치한 이 분식집은 떡볶이, 튀김, 순대, 어묵, 라면 등 다양한 메...      2
# 16  극장판 중에서도 최고라고 생각되는 작품이었지만, 네티즌들의 반응이 사골에 집중되어서...      2
# 17  한 개도 아깝다는 점수를 주고 싶지 않은데, 왜 이런 쓰레기 같은 곳에 좋은 댓글을...      1
# 18  주말 점심 가족들이랑 갔고 예약은 두달 전 했습니다. 다들 더없이 만족했고 또 오자...      4
# 19  매우 든든하게 식사하고 싶어져서 5700원짜리 직화숯불구이를 주문했는데, 제가 기대...      2
# 20  김밥 메뉴가 탁월함 면목동 타의추종 불허 비빔국수는 타 멸치국수 집에서 비빔국수보다...      4
# 21  꼬들살이 냉동 상태로 제공되어 아쉬웠지만, 채소와 고기 소스의 조합이 매우 맛있었습...      3
# 22  24시간 가마솥에서 진짜 뼈국물을 국내에 널리 알려진 설렁탕집들과 비교해보면, 신선...      2
# 23  전설! 오배넌의 정밀한 각본! 존-바뎀의 힘찬 연출! 냉혹한 두 명배우의 대결! 혼...      4
# 24  가성비가 좋지 않았어요... '대' 사이즈를 주문했는데 '소' 사이즈로 나왔고, 얇...      2
# 25  진짜 맛있었고 자주 갔었는데 최근들어 맛이 조금 달라진 것 같아요. 치즈스커트는 너...      2
# 26  [위생불량-이물질] 제 음식에서 이물질이 발견되었어요. 환불을 요청하니, 두 조각만...      2
# 27  보고 싶었던 영화인데 TV에서 못 봤어요. 한편의 어른 동화 같은 느낌이었어요. 순...      3
# 28  이곳의 가격에 비해 퀄리티는 매우 높네요. 비싼 생선을 사용하진 않아도, 같은 생선...      3
# 29  세계적으로 유명한 공연을 보러 갈 수 없어도 간접적으로라도 즐길 수 있게 해준 메가...      3
# 30  치즈렐라 버거를 할인 받아 주문했는데, 추가 메뉴를 선택해서 총 9200원을 지불했...      2
# 31  재구매 배추김치도 총각김치도 너무 맛있어서 재주문했는데 이번 김치는 양념이 저번에 ...      4
# 32  어제 만든 감자튀김은 정말 최악이었습니다. 비온 것도 아니었는데 눅눅하고 맛이 별로...      2
# 33  배달에 신경 쓰느라 현장에선 오히려 홀대 받는 느낌. 나오는 것도 밀리는 느낌. 컴...      4
# 34  비건 식당인 이곳은 제 비건 친구가 너무 좋아해서 매번 여기로 약속을 잡아요ㅋㅋㅋ ...      3
# 35  고객님이 귀찮으셨던 주문 후기를 남겨주셨네요. 저희 매장의 서비스 마인드는 아쉽게도...      3
# 36  사장님, 예전에는 그 가게에서 많은 양의 모밀을 저렴한 가격에 즐길 수 있어서 정말...      2
# 37  우리가 아는 베트남 음식과는 다름. 맛있음. 조금 특이하지만 맛있음. 쌀국수는 그 ...      3
# 38  정말 불편했어요. 약국 앞에서 아침부터 소란스러운 상황이었고, 시장 상인회엔 도움을...      1
# 39  처음엔 친절했지만.. 전화로 문의하면 일단 엄청 귀찮아 하고 무조건 방문하라고 함....      4
# 40  숨겨진 동네 맛집이에요. 평점이 없어서 아쉬워서 리뷰를 남깁니다. 사장님이 요리하시...      1
# 41  서비스에 실망했습니다. 본사 운영인 줄 알았지만 그렇지 않은 것 같아요. 문자 안내...      2
# 42  카카오점수(당시 5.0점) 믿고 갔는데 너무 실망했어요. 안주에 마늘이 떨어졌다고 ...      1
# 43  돈까스 깔끔하게 맛있습니다.  사진에는 잘 안 보이지만 두 조각이라 양이 제법 많습...      4
# 44  레벨링, 재미, 편의성, 그래픽 모두 최악. 2년 동안 기다린 보람 없음. 만족하지...      3
# 45  ㄹㅇ남자직원 왜케 말투 공격적인거에요? 밥먹고 기분좋게 카페와서 커피먹을라고 했는데...      4
# 46  이 가격에 이런 품질의 피자라니, 너무 기분이 좋아요! 도우는 매우 쫄깃하고 고구마...      3
# 47  겉은 바삭바삭한데, 치킨 메뉴가 많고 주인부부가 인상적이어서 들어갔는데 바로 나왔어...      2
# 48  단체로 와서 잘먹긴했지만 회만 먹은것도 아니고 술도 시키면서 먹고있는데 "적당히"드...      4
# 49  ★★★☆(3.5) 모둠 초밥(12,000원)은 정말 가성비가 좋아요! 처음에 참소라...      1

# %% [markdown]
# 클래스 균형을 위해 ai 가 작성한 sentence 중 하나만 random으로 choice
# - 1개의 data point에 대해서 1개는 인간, 3개는 ai 데이터
# - 결과적으로 1:3의 클래스 비율
# - 1:1로 맞춰주는 작업 수행

# %%
human_reviews = []  # 정답 data
ai_reviews = [] # 오답 data

# %%
for i, label in enumerate(train_df['label']):
    labels = [1, 2 ,3 ,4]
    labels.remove(label)
    ai_label = np.random.choice(labels)
        # 정답 label을 제외한 ai label 중에서 임의로 1가지 선택
        # 1가지만 남기기 위함
    human_reviews.append(train_df.iloc[i, label])
    ai_reviews.append(train_df.iloc[i, ai_label])

# %%
print(f'human_reviews : {len(human_reviews)}')
print(f'ai_reviews : {len(ai_reviews)}')
# Out:
# human_reviews : 50
# ai_reviews : 50

# %%
human_labels = [1] * len(human_reviews)  # 정답 레이블
ai_labels = [0] * len(ai_reviews)   # 오답 레이블

# %%
reviews = human_reviews + ai_reviews
labels = human_labels + ai_labels

print(f'reviews : {len(reviews)}')
print(f'labels : {len(labels)}')
# Out:
# reviews : 100
# labels : 100

# %% [markdown]
# # Tokenizer

# %%
# KoGPT-2 사용
tokenizer = AutoTokenizer.from_pretrained('skt/kogpt2-base-v2')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.00k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.83M [00:00<?, ?B/s]

# %%
# GPT Classifier Model
class GPTModel(nn.Module):
    def __init__(self, num_classes=2):
        super(GPTModel, self).__init__()
        self.num_classes = num_classes
        self.gpt = AutoModel.from_pretrained('skt/kogpt2-base-v2')
        self.fc = nn.Linear(768, num_classes, bias=True)

    def forward(self, input_ids, attention_mask, labels=None):
        output = self.gpt(input_ids=input_ids,
                          attention_mask=attention_mask)
        output = self.fc(output[0])
        output = output[torch.arange(self.num_classes, device=device), -1]
        return output

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
model = GPTModel()
model = model.to(device)
# Out:
# pytorch_model.bin:   0%|          | 0.00/513M [00:00<?, ?B/s]

# %%
model
# Out:
# GPTModel(
#   (gpt): GPT2Model(
#     (wte): Embedding(51200, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-11): 12 x GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (fc): Linear(in_features=768, out_features=2, bias=True)
# )

# %% [markdown]
# # DataLoader

# %%
tokenized_texts = [tokenizer.tokenize(s) for s in reviews]
len(tokenized_texts)
# Out:
# 100

# %%
# padding을 위한 max_len 확인
max_len = max([len(x) for x in tokenized_texts])

# token의 vectorization
input_ids = [tokenizer.convert_tokens_to_ids(x) for x in tokenized_texts]
# padding 추가
input_ids = pad_sequences(input_ids, maxlen=max_len, dtype='long',
                         truncating='post', padding='post')
    # dypte : 정수형(long)
    # truncating : 시퀀스 끝에서부터 데이터 편집 (시퀀스 길이가 maxlen보다 긴 경우)
    # padding : 0 추가

# %%
attention_mask = []

for seq in tqdm(input_ids):
    seq_mask = [float(i>0) for i in seq]
        # seq의 각 원소가 패딩이 아닌 경우 1.0으로 표현
    attention_mask.append(seq_mask)

train_inputs = torch.tensor(input_ids)
train_labels = torch.tensor(labels)
train_masks = torch.tensor(attention_mask)

print(f'train_inputs.shape : {train_inputs.shape}')
print(f'train_labels.shape : {train_labels.shape}')
print(f'train_masks.shape : {train_masks.shape}')
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 9981.45it/s]
# train_inputs.shape : torch.Size([100, 125])
# train_labels.shape : torch.Size([100])
# train_masks.shape : torch.Size([100, 125])

# %% [markdown]
# # Training Setting

# %%
# hyper parameter
batch_size = 2
epochs = 10
lr = 2e-5
eps = 1e-8

# %%
train_data = TensorDataset(train_inputs, train_masks, train_labels)
train_sampler = RandomSampler(train_data)
train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=batch_size)

# %%
optimizer = AdamW(model.parameters(), lr=lr, eps=eps)
criterion = nn.CrossEntropyLoss()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:457: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
# Accuracy Metric
def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return np.sum(pred_flat == labels_flat) / len(labels_flat)

# %% [markdown]
# # Train

# %%
def train(dataloader, criterion, epochs):
    for epoch in range(epochs):
        print('--------------------------------------------------------------------')
        print(f'Epoch "{epoch + 1}"')

        print('Train Mode:', end=" ")
        total_loss, train_accuracy = 0.0, 0.0
        model.train()

        for batch in tqdm(dataloader):
            batch = tuple(t.to(device) for t in batch)
            b_input_ids, b_input_mask, b_labels = batch
            outputs = model(input_ids=b_input_ids,
                            attention_mask=b_input_mask)

            loss = criterion(outputs.view(-1, 2), b_labels)
            logits = outputs.view(-1, 2)
            total_loss += loss.item()
            loss.backward()

            logits = logits.detach().cpu().numpy()
            label_ids = b_labels.to('cpu').numpy()
            train_accuracy += flat_accuracy(logits, label_ids)

            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()

        model.zero_grad()
        avg_train_loss = total_loss / len(dataloader)
        avg_train_acc = train_accuracy / len(dataloader)
        print(" Average training loss: {0:.2f}".format(avg_train_loss), end=" ")
        print(" Average training accuracy: {0:.2f}".format(avg_train_acc))

# %%
train(train_dataloader, criterion, epochs)
# Out:
# --------------------------------------------------------------------
# Epoch "1"
# Train Mode:
# 100%|██████████| 50/50 [00:08<00:00,  5.75it/s]
#  Average training loss: 0.99  Average training accuracy: 0.75
# --------------------------------------------------------------------
# Epoch "2"
# Train Mode:
# 100%|██████████| 50/50 [00:05<00:00,  9.17it/s]
#  Average training loss: 1.05  Average training accuracy: 0.74
# --------------------------------------------------------------------
# Epoch "3"
# Train Mode:
# 100%|██████████| 50/50 [00:04<00:00, 10.60it/s]
#  Average training loss: 0.64  Average training accuracy: 0.91
# --------------------------------------------------------------------
# Epoch "4"
# Train Mode:
# 100%|██████████| 50/50 [00:04<00:00, 10.43it/s]
#  Average training loss: 0.84  Average training accuracy: 0.89
# --------------------------------------------------------------------
# Epoch "5"
# Train Mode:
# 100%|██████████| 50/50 [00:04<00:00, 10.73it/s]
#  Average training loss: 1.48  Average training accuracy: 0.81
# --------------------------------------------------------------------
# Epoch "6"
# Train Mode:
# 100%|██████████| 50/50 [00:04<00:00, 10.47it/s]
#  Average training loss: 0.33  Average training accuracy: 0.91
# --------------------------------------------------------------------
# Epoch "7"
# Train Mode:
# 100%|██████████| 50/50 [00:04<00:00, 10.57it/s]
#  Average training loss: 0.39  Average training accuracy: 0.97
# --------------------------------------------------------------------
# Epoch "8"
# Train Mode:
# 100%|██████████| 50/50 [00:04<00:00, 10.73it/s]
#  Average training loss: 0.45  Average training accuracy: 0.94
# --------------------------------------------------------------------
# Epoch "9"
# Train Mode:
# 100%|██████████| 50/50 [00:04<00:00, 10.27it/s]
#  Average training loss: 0.07  Average training accuracy: 0.99
# --------------------------------------------------------------------
# Epoch "10"
# Train Mode:
# 100%|██████████| 50/50 [00:04<00:00, 10.74it/s]
#  Average training loss: 0.59  Average training accuracy: 0.94

# %%
torch.save(model.state_dict(), '/content/drive/MyDrive/Share/Personal/NLP/project/best_model.pth')

# %% [markdown]
# # Predict

# %% [markdown]
# - test 데이터도 train 데이터와 동일한 프로세스로 처리
# - train 데이터와 달리 test 데이터는 4개의 문장 중 가장 인간이 작성했을 법한 문장을 예측하는 것이기 때문에 순서대로 배치
# - 4개의 문장 중 가장 score가 높은 2개 선택

# %%
test_reviews = []

for i in range(test_df.shape[0]):
  cols = [1,2,3,4]
  test_reviews.extend(test_df.iloc[i, cols])

# %%
tokenized_texts = [tokenizer.tokenize(s) for s in test_reviews]

input_ids = [tokenizer.convert_tokens_to_ids(x) for x in tokenized_texts]
input_ids = pad_sequences(input_ids, maxlen=max_len, dtype='long', truncating='post', padding='post')

attention_masks = []

for seq in input_ids:
    seq_mask = [float(i>0) for i in seq]
    attention_masks.append(seq_mask)

test_inputs = torch.tensor(input_ids)
test_masks = torch.tensor(attention_masks)

test_data = TensorDataset(test_inputs, test_masks)
test_sampler = SequentialSampler(test_data)
test_dataloader = DataLoader(test_data, sampler=test_sampler, batch_size=batch_size)

# %%
model.eval()

preds = []

for batch in tqdm(test_dataloader):
  batch = tuple(t.to(device) for t in batch) # Batch to cuda device
  b_input_ids, b_input_mask = batch
  outputs = model(input_ids=b_input_ids,
                  attention_mask=b_input_mask)

  logits = outputs.view(-1, 2).detach().cpu().numpy()
  preds.extend(logits)

preds = np.array(preds)
# Out:
# 100%|██████████| 2200/2200 [00:57<00:00, 38.18it/s]

# %%
pred_labels = []

for i in range(0,preds.shape[0],4):
  tmp = preds[i:i+4,1] # 4 문장씩 검사
  label1 = np.argmax(tmp) # 가장 높은 score
  tmp[label1] = -np.inf
  label2 = np.argmax(tmp) # 두번째로 높은 score

  label = str(label1 + 1) + str(label2 + 1)
  pred_labels.append(label)

# %% [markdown]
# # Submission

# %%
submit = pd.read_csv('/content/drive/MyDrive/Share/Personal/NLP/data/sample_submission.csv')
submit['label'] = pred_labels
submit
# Out:
#              id label
# 0     TEST_0000    34
# 1     TEST_0001    13
# 2     TEST_0002    24
# 3     TEST_0003    21
# 4     TEST_0004    32
# ...         ...   ...
# 1095  TEST_1095    21
# 1096  TEST_1096    24
# 1097  TEST_1097    41
# 1098  TEST_1098    41
# 1099  TEST_1099    42
#
# [1100 rows x 2 columns]

# %%
submit.to_csv('/content/drive/MyDrive/Share/Personal/NLP/project/binary_clf_gpt_submission.csv', index=False)
